# %% [markdown]
# # TSD MODELLE

# %%
import matplotlib.pyplot as plt
import numpy as np

# Phänomene inklusive "Total"
phenomena = ['FCR', 'Gap.', 'BCR', 'SGF', 'Alle']

# Modelle
models = ['T_K', 'TB_K', 'K_K', 'T_B', 'TB_B', 'K_B']

# Konfigurationen
configs = ['TIGER', 'TüBa', 'Beispiele']

data = {'TüBa': {'T_K': [.7504, .7459, .7107, .7048, .8257],
                    'TB_K': [.7064, .7253, .6807, .7700, .8168],
                    'K_K': [.7534, .7393, .7268, .7577, .8294],
                    'T_B': [.7127, .7109, .6533, .6759, .8089],
                    'TB_B': [.6682, .6798, .6836, .7439, .7882],
                    'K_B': [.7324, .7121, .6764, .6855, .8183],
                },
        'TIGER': {'T_K': [.6562, .4246, .4224, .6622, .7256],
            'TB_K': [.5652, .3846, .3439, .6265, .6906],
            'K_K': [.6519, .4192, .4137, .6639, .7241],
            'T_B': [.6023, .4032, .3752, .6284, .7032],
            'TB_B': [.5485, .3649, .3342, .6193, .6719],
            'K_B': [.6288, .4270, .3976, .5984, .7151],
        },
        'Beispiele': {'T_K': [.3939, .2536, .4555, .3083, .3379],
            'TB_K': [.3521, .2599, .4304, .3901, .3129],
            'K_K': [.3704, .2536, .4555, .3901, .3185],
            'T_B': [.3388, .2874, .4304, .3406, .3239],
            'TB_B': [.3379, .2748, .4304, .3901, .3159],
            'K_B': [.3521, .2804, .4304, .3901, .3245],
        }
}

data_em = {'TüBa': {'T_K': [.0, .0, .0, .0, .0056],
                    'TB_K': [.0, .0, .0, .0, .0056],
                    'K_K': [.0, .0, .0, .0, .0056],
                    'T_B': [.0, .0, .0, .0, .0028],
                    'TB_B': [.0, .0, .0, .0, .0056],
                    'K_B': [.0, .0, .0, .0, .0028],
                },
        'TIGER': {'T_K': [.0044, .0, .0, .0, .0027],
            'TB_K': [.0, .0, .0, .0, .0020],
            'K_K': [.0066, .0, .0, .0, .0034],
            'T_B': [.0, .0, .0, .0, .0013],
            'TB_B': [.0, .0, .0, .0, .0020],
            'K_B': [.0, .0, .0, .0, .0013],
        },
        'Beispiele': {'T_K': [.0, .0, .0, .0, .0],
            'TB_K': [.0, .0, .0, .0, .0],
            'K_K': [.0, .0, .0, .0, .0],
            'T_B': [.0, .0, .0, .0, .0],
            'TB_B': [.0, .0, .0, .0, .0],
            'K_B': [.0, .0, .0, .0, .0],
        }
}

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

colors = [(0.4316, 0.5667, 1.0), (0.1925, 0.9975, 0.3), (0.9392, 0.2529, 0.4869), (0.1216, 0.4667, 0.7059), (0.1725, 0.6275, 0.1725), (0.7392, 0.1529, 0.1569)]

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('BLEU-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data_em[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('EM-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %% [markdown]
# # EXACT MATCH MODELLE

# %%
import matplotlib.pyplot as plt
import numpy as np

# Phänomene inklusive "Total"
phenomena = ['FCR', 'Gap.', 'BCR', 'SGF', 'Alle']

# Modelle
models = ['T_K_Sauber', 'TB_K_Sauber', 'K_K_Sauber', 'T_B_Sauber', 'TB_B_Sauber', 'K_B_Sauber']

# KonfiguratiEinn
configs = ['TIGER', 'TüBa', 'Beispiele']

data = {'TüBa': {'T_K_Sauber': [.8703, .8568, .8507, .8616, .8985],
                    'TB_K_Sauber': [.8591, .8599, .8757, .8793, .9040],
                    'K_K_Sauber': [.8784, .8694, .8253, .8794, .9031],
                    'T_B_Sauber': [.8179, .8141, .8063, .8601, .8629],
                    'TB_B_Sauber': [.8671, .8552, .8846, .8769, .9045],
                    'K_B_Sauber': [.8763, .8411, .8223, .8831, .9030],
                },
        'TIGER': {'T_K_Sauber': [.8392, .6818, .7131, .8435, .8063],
            'TB_K_Sauber': [.7891, .6680, .6622, .8238, .7616],
            'K_K_Sauber': [.8457, .6865, .7215, .8374, .8113],
            'T_B_Sauber': [.8883, .7483, .7973, .8867, .8658],
            'TB_B_Sauber': [.8049, .6634, .6759, .8317, .7725],
            'K_B_Sauber': [.8945, .7398, .8015, .8773, .8674],
        },
        'Beispiele': {'T_K_Sauber': [.7639, .6155, 1.0, .7017, .7245],
            'TB_K_Sauber': [.6858, .6345, .7426, .5039, .6839],
            'K_K_Sauber': [.7639, .6539, 1.0, .7017, .7436],
            'T_B_Sauber': [.9203, .7685, .7426, .7017, .8273],
            'TB_B_Sauber': [.8150, .6364, .7426, .7109, .7222],
            'K_B_Sauber': [.8129, .7451, 1.0, .7017, .8049],
        }
}

data_em = {'TüBa': {'T_K_Sauber': [.2793, .2063, .0, .0689, .4],
                    'TB_K_Sauber': [.2432, .2698, .1667, .0, .4528],
                    'K_K_Sauber': [.3514, .2857, .0, .1034, .4444],
                    'T_B_Sauber': [.2793, .1587, .0, .4138, .4111],
                    'TB_B_Sauber': [.2342, .2698, .25, .1379, .4417],
                    'K_B_Sauber': [.3243, .2063, .0833, .4138, .4611],
                },
        'TIGER': {'T_K_Sauber': [.2079, .0194, .0451, .125, .8063],
            'TB_K_Sauber': [.0252, .0, .0, .0, .0217],
            'K_K_Sauber': [.2164, .0291, .0526, .0972, .1683],
            'T_B_Sauber': [.3466, .1359, .1353, .4583, .3243],
            'TB_B_Sauber': [.1008, .0, .0, .0278, .0733],
            'K_B_Sauber': [.3697, .1456, .1429, .4722, .3392],
        },
        'Beispiele': {'T_K_Sauber': [.3333, .0, 1.0, .0, .25],
            'TB_K_Sauber': [.3333, .0, .0, .0, .125],
            'K_K_Sauber': [.3333, .0, 1.0, .0, .25],
            'T_B_Sauber': [.6667, .25, .0, .0, .375],
            'TB_B_Sauber': [.3333, .0, .0, .0, .125],
            'K_B_Sauber': [.3333, .25, 1.0, .0, .375],
        }
}

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('BLEU-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data_em[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('EM-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %% [markdown]
# # MERGED Testdaten

# %%
import matplotlib.pyplot as plt
import numpy as np

# Phänomene inklusive "Total"
phenomena = ['FCR', 'Gap.', 'BCR', 'SGF', 'Alle']

# Modelle
models = ['T_K', 'TB_K', 'K_K', 'T_B', 'TB_B', 'K_B']

# KonfiguratiEinn
configs = ['EG+UD', 'EG+UD_kCCE',  'AG+UD', 'EG+AD', 'AG+AD']

# %%
data = {'EG+UD': {'T_K': [.8447, .7473, .7265, .8488, .8334],
                    'TB_K': [.8012, .7383, .6798, .8399, .8034],
                    'K_K': [.8515, .7544, .7344, .8496, .8381],
                    'T_B': [.8878, .7927, .8026, .8787, .8782],
                    'TB_B': [.8158, .7337, .6931, .8474, .8114],
                    'K_B': [.8948, .7866, .8062, .8789, .8823],
                },
        'EG+UD_kCCE': {'T_K': [.8413, .7461, .7215, .8458, .8310],
                        'TB_K': [.8017, .7356, .6819, .8389, .8053],
                        'K_K': [.8444, .7499, .7244, .8481, .8336],
                        'T_B': [.8848, .7812, .7889, .9103, .8701],
                        'TB_B': [.8026, .7319, .6958, .8422, .8035],
                        'K_B': [.8851, .7814, .7886, .9061, .87],
                },
        'AG+UD': {'T_K': [.8392, .7549, .7287, .8426, .8315],
                        'TB_K': [.8121, .7397, .6869, .8420, .8105],
                        'K_K': [.8455, .7588, .7343, .8369, .8369],
                        'T_B': [.8744, .7932, .7994, .8983, .8667],
                        'TB_B': [.8394, .7472, .7055, .8631, .8309],
                        'K_B': [.8792, .7847, .7906, .9105, .8703],
                },
        'EG+AD': {'T_K': [.8422, .7483, .7269, .8494, .8309],
                        'TB_K': [.8012, .7383, .6798, .8399, .8034],
                        'K_K': [.8508, .7514, .7335, .8526, .8396],
                        'T_B': [.8971, .7949, .8067, .9282, .8822],
                        'TB_B': [.8158, .7337, .6931, .8474, .8114],
                        'K_B': [.8982, .7802, .8107, .9148, .8828],
                },
        'AG+AD': {'T_K': [.8554, .7588, .7573, .8416, .8457],
                        'TB_K': [.8130, .7418, .6869, .8408, .8113],
                        'K_K': [.8570, .7639, .7627, .8495, .8458],
                        'T_B': [.8968, .8130, .8193, .9142, .8883],
                        'TB_B': [.8425, .7468, .7129, .8671, .8334],
                        'K_B': [.9069, .8084, .8308, .9173, .8938],
                }
}

data_em = {'EG+UD': {'T_K': [.2215, .0904, .0414, .1089, .2425],
                    'TB_K': [.0664, .1024, .0138, .0, .1632],
                    'K_K': [.2419, .1265, .0483, .0990, .2589],
                    'T_B': [.3339, .1446, .1241, .4455, .3528],
                    'TB_B': [.1261, .1024, .0207, .0594, .1942],
                    'K_B': [.3612, .1687, .1379, .4554, .3792],
                },
        'EG+UD_kCCE': {'T_K': [.2215, .0904, .0345, .0891, .2388],
                        'TB_K': [.0443, .1024, .0138, .0, .1495],
                        'K_K': [.2249, .1024, .0276, .1188, .2470],
                        'T_B': [.3322, .1386, .1379, .4752, .3455],
                        'TB_B': [.0869, .0904, .0276, .0198, .1632],
                        'K_B': [.3305, .1446, .1241, .4455, .3437],
                },
        'AG+UD': {'T_K': [.1704, .1024, .0345, .0297, .2151],
                        'TB_K': [.1175, .0904, .0138, .0297, .1923],
                        'K_K': [.2095, .1084, .0483, .0297, .2443],
                        'T_B': [.2658, .1566, .1379, .3663, .3108],
                        'TB_B': [.2232, .1024, .0207, .1683, .2607],
                        'K_B': [.2998, .1747, .1379, .4554, .3537],
                },
        'EG+AD': {'T_K': [.2181, .1145, .0552, .1089, .2552],
                        'TB_K': [.0664, .1024, .0138, .0, .1632],
                        'K_K': [.2521, .1205, .0689, .0990, .2780],
                        'T_B': [.3935, .2048, .1793, .5545, .4157],
                        'TB_B': [.1261, .1024, .0207, .0594, .1942],
                        'K_B': [.4055, .1988, .1793, .4951, .4239],
                },
        'AG+AD': {'T_K': [.2299, .1205, .0621, .0693, .2644],
                        'TB_K': [.1141, .0904, .0138, .0198, .1896],
                        'K_K': [.2589, .1325, .0897, .0792, .2789],
                        'T_B': [.3714, .2108, .1793, .5644, .4075],
                        'TB_B': [.2368, .0964, .0207, .1683, .2689],
                        'K_B': [.4003, .2229, .1517, .5149, .4257],
                }
}

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 5, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('BLEU-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 5, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data_em[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('EM-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %% [markdown]
# ## Merged Experimente

# %%
import matplotlib.pyplot as plt
import numpy as np

# Phänomene inklusive "Total"
phenomena = ['FCR', 'Gap.', 'BCR', 'SGF', 'Alle']

# Modelle
models = ['K_K', 'K_B']

# Konfigurationen
configs = ['AG+AD_Gem.', 'AG+AD_FR', 'AG+AD_FE', 'AG+AD']


data = {
        'AG+AD_Gem.': {
                        'K_K': [.8616, .7646, .7613, .8522, .8497],
                        'K_B': [.9074, .8055, .8247, .9207, .8923],
                },
        'AG+AD_FR': {
                        'K_K': [.8479, .7642, .7483, .8448, .8385],
                        'K_B': [.8913, .8054, .8025, .9009, .8782],
                },
        'AG+AD_FE': {
                        'K_K': [.8653, .7659, .7816, .8528, .8501],
                        'K_B': [.9140, .8269, .8638, .9199, .8991],
                },
        'AG+AD':{
                        'K_K': [.8570, .7639, .7627, .8495, .8458],
                        'K_B': [.9069, .8084, .8308, .9173, .8938],
                }
}

data_em = { 
        'AG+AD_Gem.': {
                        'K_K': [.2624, .1145, .0689, .0891, .2826],
                        'K_B': [.3969, .2169, .1517, .5049, .4193],
                },
        'AG+AD_FR': {
                        'K_K': [.2266, .1205, .0689, .0396, .2552],
                        'K_B': [.3646, .2349, .1517, .3960, .3902],
                },
        'AG+AD_FE': {
                        'K_K': [.2828, .1145, .1172, .0891, .2954],
                        'K_B': [.3987, .2289, .2207, .5149, .4229],
                },
        'AG+AD': {
                        'K_K': [.2589, .1325, .0897, .0792, .2789],
                        'K_B': [.4003, .2229, .1517, .5149, .4257],
        }
}

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

colors = [(0.9992, 0.2529, 0.4869), (0.7392, 0.1529, 0.1569)]

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 4, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('BLEU-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 4, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data_em[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('EM-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %% [markdown]
# # 10 Epochen Eval

# %%
import matplotlib.pyplot as plt
import numpy as np

# Phänomene inklusive "Total"
phenomena = ['FCR', 'Gap.', 'BCR', 'SGF', 'Alle']

# Modelle
models = ['T_K', 'TB_K', 'K_K', 'T_B', 'TB_B', 'K_B']

# KonfiguratiEinn
configs = ['EG+UD', 'EG+UD_kCCE',  'AG+UD', 'EG+AD', 'AG+AD']

# %%
data50 = {'EG+UD': {'T_K': [.8658, .7592, .7593, .8615, .8522],
                    'TB_K': [.8129, .7387, .6859, .8422, .8111],
                    'K_K': [.8679, .7641, .7659, .8657, .8543],
                    'T_B': [.9014, .7989, .8194, .8934, .8999],
                    'TB_B': [.8359, .7385, .7014, .8614, .8260],
                    'K_B': [.9027, .7968, .8178, .9099, .8925],
                },
        'EG+UD_kCCE': {'T_K': [.8634, .7596, .7514, .8639, .8486],
                        'TB_K': [.8065, .7393, .6866, .8320, .8073],
                        'K_K': [.8665, .7618, .7507, .8707, .8519],
                        'T_B': [.8993, .7955, .8061, .9215, .8828],
                        'TB_B': [.8236, .7349, .6950, .8519, .8168],
                        'K_B': [.9015, .7962, .8162, .8959, .8841],
                },
        'AG+UD': {'T_K': [.8572, .7708, .7672, .8497, .8479],
                        'TB_K': [.8221, .7424, .6914, .8389, .8168],
                        'K_K': [.8606, .7683, .7609, .8592, .8504],
                        'T_B': [.8849, .7958, .8137, .9162, .8751],
                        'TB_B': [.8555, .7528, .7225, .8846, .8432],
                        'K_B': [.8891, .7995, .8147, .9206, .8801],
                },
        'EG+AD': {'T_K': [.8729, .7721, .7685, .8629, .8569],
                        'TB_K': [.8129, .7387, .6859, .8422, .8111],
                        'K_K': [.8816, .7839, .7874, .8678, .8656],
                        'T_B': [.9242, .8324, .8676, .9425, .9100],
                        'TB_B': [.8359, .7385, .7014, .8614, .8260],
                        'K_B': [.9229, .8119, .8665, .9362, .9087],
                },
        'AG+AD': {'T_K': [.8783, .7824, .7961, .8692, .8643],
                        'TB_K': [.8269, .7425, .6927, .8443, .8206],
                        'K_K': [.8770, .7831, .7959, .8773, .8646],
                        'T_B': [.9123, .8372, .8608, .9373, .9051],
                        'TB_B': [.8627, .7577, .7424, .8809, .8497],
                        'K_B': [.9208, .8429, .8777, .9326, .9119],
                },
        'AG+AD_Gem.': {
                        'K_K': [.8801, .7827, .7970, .8823, .8666],
                        'K_B': [.9267, .8343, .8763, .9403, .9153],
                },
        'AG+AD_FR': {
                        'K_K': [.8717, .7949, .7765, .8574, .8616],
                        'K_B': [.9086, .8335, .8416, .9126, .8956],
                },
        'AG+AD_FE': {
                        'K_K': [.8869, .7999, .8168, .8804, .8732],
                        'K_B': [.9253, .8489, .8965, .9353, .9129],
                }
}

data_em50 = {'EG+UD': {'T_K': [.2913, .0964, .0828, .1980, .2889],
                    'TB_K': [.1431, .0964, .0207, .0396, .2051],
                    'K_K': [.3015, .1386, .0897, .1980, .3136],
                    'T_B': [.3765, .1446, .1517, .5149, .3919],
                    'TB_B': [.2181, .0964, .0276, .1386, .2525],
                    'K_B': [.3901, .1687, .1655, .5149, .4102],
                },
        'EG+UD_kCCE': {'T_K': [.2947, .1024, .0689, .1584, .2862],
                        'TB_K': [.0988, .1024, .0138, .0198, .1759],
                        'K_K': [.2998, .1145, .0689, .2178, .3017],
                        'T_B': [.3697, .1506, .1517, .5347, .3728],
                        'TB_B': [.1942, .0904, .0207, .0792, .2233],
                        'K_B': [.3799, .1928, .1586, .4951, .3838],
                },
        'AG+UD': {'T_K': [.2198, .1145, .0828, .0891, .2534],
                        'TB_K': [.1669, .0843, .0069, .0792, .2224],
                        'K_K': [.2658, .1024, .0759, .1683, .2889],
                        'T_B': [.2998, .1687, .1655, .4851, .3437],
                        'TB_B': [.2692, .1084, .0345, .2574, .3017],
                        'K_B': [.3373, .1747, .1586, .4951, .3810],
                },
        'EG+AD': {'T_K': [.3407, .1446, .1103, .1988, .3373],
                        'TB_K': [.1431, .0964, .0207, .0396, .2051],
                        'K_K': [.3475, .1446, .1310, .2178, .3446],
                        'T_B': [.4599, .3133, .3035, .6337, .4849],
                        'TB_B': [.2181, .0964, .0276, .1386, .2525],
                        'K_B': [.4702, .2711, .3249, .5842, .4913],
                },
        'AG+AD': {'T_K': [.3049, .1506, .1172, .1782, .3181],
                        'TB_K': [.1857, .0783, .0069, .0792, .2334],
                        'K_K': [.3271, .1566, .1310, .2574, .3455],
                        'T_B': [.4276, .2952, .3172, .6535, .4713],
                        'TB_B': [.2743, .1084, .0483, .2376, .3036],
                        'K_B': [.4480, .3072, .3103, .6039, .4813],
                },
        'AG+AD_Gem.': {
                        'K_K': [.3339, .1627, .1241, .2871, .3473],
                        'K_B': [.4634, .2952, .2759, .6139, .4877],
                },
        'AG+AD_FR': {
                        'K_K': [.3203, .1566, .0966, .1386, .3236],
                        'K_B': [.3969, .2771, .2138, .4554, .4266],
                },
        'AG+AD_FE': {
                        'K_K': [.3509, .1687, .1586, .2772, .3609],
                        'K_B': [.4463, .3072, .3310, .5743, .4740],
                }
}

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

colors = [(0.4316, 0.5667, 1.0), (0.1925, 0.9975, 0.3), (0.9392, 0.2529, 0.4869), (0.1216, 0.4667, 0.7059), (0.1725, 0.6275, 0.1725), (0.7392, 0.1529, 0.1569)]

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 5, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data50[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('BLEU-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 5, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data_em50[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('EM-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %%
# Phänomene inklusive "Total"
phenomena = ['FCR', 'Gap.', 'BCR', 'SGF', 'Alle']

# Modelle
models = ['K_K', 'K_B']

# Konfigurationen
configs = ['AG+AD_Gem.', 'AG+AD_FR', 'AG+AD_FE']

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

colors = [(0.9392, 0.2529, 0.4869), (0.7392, 0.1529, 0.1569)]

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data50[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('BLEU-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm speichern (optional)
# fig.savefig('diagrams/EK_Werte_Kubplots.png')

# Diagramm anzeigen

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data_em50[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('EM-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %% [markdown]
# # Eval mit Fairen Daten

# %%
# 5 Epochen
import matplotlib.pyplot as plt
import numpy as np

# Phänomene inklusive "Total"
phenomena = ['FCR', 'Gap.', 'BCR', 'SGF', 'Alle']

# Modelle
models = ['T_K', 'TB_K', 'K_K', 'T_B', 'TB_B', 'K_B']

# Konfigurationen
configs = ['AG+AD + faire Eval. (5 Epochen)', 'AG+AD + faire Eval. (10 Epochen)']

data = {'AG+AD + faire Eval. (5 Epochen)': {   'T_K': [.8554, .7974, .7983, .8489, .8322],
                                    'TB_K':[.8304, .7799, .7523, .8445, .8014],
                                    'K_K': [.8561, .8038, .8019, .8564, .8328],
                                    'T_B': [.8845, .8326, .8362, .9012, .8729],
                                    'TB_B':[.8531, .7900, .7632, .8759, .8239],
                                    'K_B': [.8924, .8309, .8416, .8927, .8748],
                                },
        'AG+AD + faire Eval. (10 Epochen)': {  'T_K': [.8685, .8151, .8215, .8684, .8496],
                                    'TB_K':[.8380, .7809, .7552, .8536, .8083],
                                    'K_K': [.8639, .8154, .8129, .8720, .8456],
                                    'T_B': [.8938, .8432, .8677, .9125, .8863],
                                    'TB_B':[.8645, .7939, .7809, .8904, .8369],
                                    'K_B': [.8971, .8495, .8691, .9259, .8898],
                                },
}

data_em = {'AG+AD + faire Eval. (5 Epochen)': {'T_K': [.2116, .1397, .0135, .0645, .2313],
                                    'TB_K':[.1672, .1397, .0676, .0161, .1797],
                                    'K_K': [.2491, .1732, .0811, .0645, .2438],
                                    'T_B': [.2935, .1844, .0811, .5, .3452],
                                    'TB_B':[.2492, .1397, .0135, .1452, .2402],
                                    'K_B': [.3345, .2067, .0676, .4359, .3629],
                                },
        'AG+AD + faire Eval. (10 Epochen)': {  'T_K': [.2628, .1564, .0676, .1774, .2794],
                                    'TB_K':[.2048, .1173, .0405, .0806, .2064],
                                    'K_K': [.2765, .1620, .1081, .1774, .2883],
                                    'T_B': [.3413, .2569, .2432, .5645, .4075],
                                    'TB_B':[.2662, .1453, .0270, .1935, .2651],
                                    'K_B': [.3481, .2626, .2297, .5, .4110],
                                },
                }

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

colors = [(0.4316, 0.5667, 1.0), (0.1925, 0.9975, 0.3), (0.9392, 0.2529, 0.4869), (0.1216, 0.4667, 0.7059), (0.1725, 0.6275, 0.1725), (0.7392, 0.1529, 0.1569)]

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('BLEU-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data_em[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('EM-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %% [markdown]
# # MASKED

# %%
# Konfigurationen
configs = ['5 Epochen (Maskiert)', '5 Epochen (Unmaskiert)', '10 Epochen (Maskiert)', '10 Epochen (Unmaskiert)']
# Modelle
models = ['MK_K', 'MK_B']

# EVAL auf Maskierten daten
data_masked = {'5 Epochen (Maskiert)': {
                    'MK_K': [.7607, .5478, .7847, .7213, .6607],
                    'MK_B': [.8969, .7803, .8791, .8606, .8513],
                },
                '10 Epochen (Maskiert)': {
                    'MK_K': [.8885, .7764, .8571, .8243, .8381],
                    'MK_B': [.9013, .7902, .8944, .8478, .8520],
                },
                '5 Epochen (Unmaskiert)': {
                    'MK_K': [.8017, .7444, .6888, .8448, .8066],
                    'MK_B': [.8030, .7454, .6894, .8483, .8085],
                },
                '10 Epochen (Unmaskiert)': {
                    'MK_K': [.8019, .7456, .6886, .8448, .8075],
                    'MK_B': [.8024, .7464, .6904, .8481, .8082],
                },
}

data_maskedEm = {'5 Epochen (Maskiert)': {
                    'MK_K': [.5455, .2934, .3125, .1029, .5003],
                    'MK_B': [.6450, .3595, .4688, .5367, .6129],
                },
                '10 Epochen (Maskiert)': {
                    'MK_K': [.5812, .3182, .3594, .2721, .5428],
                    'MK_B': [.6613, .3926, .5104, .5588, .6326],
                },
                '5 Epochen (Unmaskiert)': {
                    'MK_K': [.0273, .0939, .0138, .0, .1468],
                    'MK_B': [.0273, .0964, .0138, .0, .1495],
                },
                '10 Epochen (Unmaskiert)': {
                    'MK_K': [.0273, .0964, .0138, .0, .1486],
                    'MK_B': [.0273, .0964, .0138, .0, .1504],
                },
}

# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

colors = ['tab:pink', 'tab:purple']

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 4, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data_masked[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('BLEU-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1])

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 4, figsize=(18, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data_maskedEm[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('EM-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %% [markdown]
# # Neuer TIGER (erweitert)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Phänomene inklusive "Total"
phenomena = ['FCR', 'Gap.', 'BCR', 'SGF', 'Alle']

# Modelle
models = ['TE_K', 'TE_B']
# Konfigurationen
configs = ['TIGER_Erw. (5 Epochen)', 'TIGER_Erw. (10 Epochen)']
# EVAL auf Maskierten daten
data_masked = {'TIGER_Erw. (5 Epochen)': {
                    'TE_K': [.8603, .7643, .7672, .8634, .8479],
                    'TE_B': [.9137, .8211, .8515, .9197, .9029],
                },
                'TIGER_Erw. (10 Epochen)': {
                    'TE_K': [.8877, .7862, .8055, .9005, .8713],
                    'TE_B': [.9275, .8416, .8999, .9424, .9196],
                }
}

data_maskedEm = {'TIGER_Erw. (5 Epochen)': {
                    'TE_K': [.2759, .1265, .0966, .1584, .2917],
                    'TE_B': [.4276, .2409, .2276, .5941, .4531],
                },
                'TIGER_Erw. (10 Epochen)': {
                    'TE_K': [.3612, .1807, .1586, .4059, .3765],
                    'TE_B': [.4515, .3193, .3517, .7129, .4941],
                }
}

# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15
colors = [(0.5, 0.9, 0.9), (0.0, 0.5, 0.5)]

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data_masked[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('BLEU-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1])

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes[i].bar(x + j*width, data_maskedEm[config][model], width, label=model, color=colors[j])
        axes[i].set_title(config, fontsize=20)
        axes[i].set_xticks(x + width)
        axes[i].set_xticklabels(phenomena, fontsize=20)
        axes[0].tick_params(axis='y', labelsize=20) 
        axes[0].set_ylabel('EM-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()

# %% [markdown]
# # Optimierungsergebnisse

# %%
import matplotlib.pyplot as plt
import numpy as np

# Phänomene inklusive "Total"
phenomena = ['FCR', 'Gap.', 'BCR', 'SGF', 'Alle']

# Modelle
models = ['K_BLEU', 'K_EM', 'K_BLEU+EM', 'K_B5', 'K_B10']
# Konfigurationen
configs = ['']
# EVAL auf Maskierten daten
data_optim = {'': {
                    'K_BLEU': [.8193, .8392, .8714, .9375, .9104],
                    'K_EM': [.8811, .7819, .7952, .8509, .8701],
                    'K_BLEU+EM': [.9134, .8111, .8408, .9255, .8952],
                    'K_B5': [.9140, .8269, .8638, .9199, .8991],
                    'K_B10': [.9253, .8489, .8965, .9353, .9129],
                }
}

data_optimEm = {'': {
                    'K_BLEU': [.3901, .2048, .2966, .5149, .3236],
                    'K_EM': [.2658, .0783, .1379, .2376, .1969],
                    'K_BLEU+EM': [.3492, .1506, .2138, .4555, .2826],
                    'K_B5': [.3987, .2289, .2207, .5149, .4229],
                    'K_B10': [.4463, .3072, .3310, .5743, .4740],
                }
}

# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15
colors = [(1.0, 0.8, 0.0), (1.0, 0.7, 0.3), (1.0, 0.5, 0.0), (0.7392, 0.1529, 0.1569, 0.8), (0.7392, 0.1529, 0.1569)]

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 1, figsize=(12, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes.bar(x + j*width, data_optim[config][model], width, label=model, color=colors[j])
        axes.set_title(config, fontsize=20)
        axes.set_xticks(x + width)
        axes.set_xticklabels(phenomena, fontsize=20)
        axes.tick_params(axis='y', labelsize=20) 
        axes.set_ylabel('BLEU-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1])

# %%
# X-Achse für jedes Phänomen
x = np.arange(len(phenomena))

# Balkenbreite
width = 0.15

colors = [(1.0, 0.8, 0.0), (1.0, 0.7, 0.3), (1.0, 0.5, 0.0), (0.7392, 0.1529, 0.1569, 0.8), (0.7392, 0.1529, 0.1569)]

# Subplots erstellen (5 Datensätze)
fig, axes = plt.subplots(1, 1, figsize=(12, 6), sharey=True)

for i in range(len(configs)):
    config = configs[i]
    for j, model in enumerate(models):
        axes.bar(x + j*width, data_optimEm[config][model], width, label=model, color=colors[j])
        axes.set_title(config, fontsize=20)
        axes.set_xticks(x + width)
        axes.set_xticklabels(phenomena, fontsize=20)
        axes.tick_params(axis='y', labelsize=20) 
        axes.set_ylabel('EM-Werte', fontsize=20)

# Legende
fig.legend(models, loc='lower center', ncol=len(models), fontsize=20, title='Modelle', title_fontsize=20)
plt.tight_layout(rect=[0, 0.16, 1, 1]) 

# Diagramm anzeigen
plt.show()
